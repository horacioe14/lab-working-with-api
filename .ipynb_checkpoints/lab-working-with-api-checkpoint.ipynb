# %% [markdown]
# ## WebScraping V: rise of the wrappers

# %%
pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\horacio\anaconda3\lib\site-packages (2.18.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\horacio\anaconda3\lib\site-packages (from spotipy) (1.26.5)
# Requirement already satisfied: six>=1.15.0 in c:\users\horacio\anaconda3\lib\site-packages (from spotipy) (1.15.0)
# Requirement already satisfied: requests>=2.25.0 in c:\users\horacio\anaconda3\lib\site-packages (from spotipy) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\horacio\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\horacio\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\horacio\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2020.6.20)

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="d151bde53dbd4ba0a64a51af0beb8ba1",
                                                           client_secret="2c1899472adb4da58dfad53428c612fb"))

results = sp.search(q='artist:The Strokes', limit=1)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=artist%3AThe+Strokes&type=track&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#        'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#        'id': '0epOFNiUfyON9EYx7Tpr6V',
#        'name': 'The Strokes',
#        'type': 'artist',
#        'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2xkZV2Hl1Omi8rk2D7t5lN'},
#      'href': 'https://api.spotify.com/v1/albums/2xkZV2Hl1Omi8rk2D7t5lN',
#      'id': '2xkZV2Hl1Omi8rk2D7t5lN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bfa99afb5ef0d26d5064b23b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bfa99afb5ef0d26d5064b23b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bfa99afb5ef0d26d5064b23b',
#        'width': 64}],
#      'name': 'The New Abnormal',
#      'release_date': '2020-04-10',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:2xkZV2Hl1Omi8rk2D7t5lN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#       'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#       'id': '0epOFNiUfyON9EYx7Tpr6V',
#       'name': 'The Strokes',
#       'type': 'artist',
#       'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 309053,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC11902726'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5ruzrDWcT0vuJIOMW7gMnW'},
#     'href': 'https://api.spotify.com/v1/tracks/5ruzrDWcT0vuJIOMW7gMnW',
#     'id': '5ruzrDWcT0vuJIOMW7gMnW',
#     'is_local': False,
#     'name': 'The Adults Are Talking',
#     'popularity': 80,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f0465f3bda33cf516d1407ae7f6f36674c81bd35?cid=d151bde53dbd4ba0a64a51af0beb8ba1',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5ruzrDWcT0vuJIOMW7gMnW'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=artist%3AThe+Strokes&type=track&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 1070}}

# %%
len(results['tracks']['items'])
# Out:
# 1

# %%
results.keys() # We can see that we only have tracks
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys() # Let's check the values
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
results["tracks"]["href"] # Query we have searched
# Out:
# 'https://api.spotify.com/v1/search?query=artist%3AThe+Strokes&type=track&offset=0&limit=1'

# %%
results["tracks"]["items"][0].keys() #items (actual tracks)
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results["tracks"]["items"][0]['name']
# Out:
# 'The Adults Are Talking'

# %%
# Info that might help you navegate through the API
results["tracks"]["limit"]#Limit we have chosen
results["tracks"]["next"] #link to the next page (next 50 tracks)
results["tracks"]["offset"] # Actual offset (starting point)
results["tracks"]["previous"] #Previous search
results["tracks"]["total"] # Number of matches
# Out:
# 1070

# %% [markdown]
# #### User playlists

# %%
playlist = sp.user_playlist_tracks("spotify", "12Wbv8sIx84T5uh6iOoJ7V")
playlist#.keys() # Let's look at items and total:
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/12Wbv8sIx84T5uh6iOoJ7V/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2018-07-19T13:11:46Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#     'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#     'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#     'type': 'user',
#     'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2HubQ6TEbD7HknCNrBsqhR'},
#        'href': 'https://api.spotify.com/v1/artists/2HubQ6TEbD7HknCNrBsqhR',
#        'id': '2HubQ6TEbD7HknCNrBsqhR',
#        'name': 'Marcelo Camelo',
#        'type': 'artist',
#        'uri': 'spotify:artist:2HubQ6TEbD7HknCNrBsqhR'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1NP7PX0MQPH6pLHr2R8e9K'},
#      'href': 'https://api.spotify.com/v1/albums/1NP7PX0MQPH6pLHr2R8e9K',
#      'id': '1NP7PX0MQPH6pLHr2R8e9K',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739567789633ace59e4e2f2a9d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029567789633ace59e4e2f2a9d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519567789633ace59e4e2f2a9d',
#        'width': 64}],
#      'name': 'Toque Dela',
#      'release_date': '2011-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:1NP7PX0MQPH6pLHr2R8e9K'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2HubQ6TEbD7HknCNrBsqhR'},
#       'href': 'https://api.spotify.com/v1/artists/2HubQ6TEbD7HknCNrBsqhR',
#       'id': '2HubQ6TEbD7HknCNrBsqhR',
#       'name': 'Marcelo Camelo',
#       'type': 'artist',
#       'uri': 'spotify:artist:2HubQ6TEbD7HknCNrBsqhR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 323280,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'BRZE51100005'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0A0eOcimSNRs2EQQlH7FFJ'},
#     'href': 'https://api.spotify.com/v1/tracks/0A0eOcimSNRs2EQQlH7FFJ',
#     'id': '0A0eOcimSNRs2EQQlH7FFJ',
#     'is_local': False,
#     'name': 'Três Dias',
#     'popularity': 27,
#     'preview_url': None,
#     'track': True,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:0A0eOcimSNRs2EQQlH7FFJ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-07-20T17:29:03Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#     'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#     'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#     'type': 'user',
#     'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6pmxr66tMAePxzOLfjGNcX'},
#        'href': 'https://api.spotify.com/v1/artists/6pmxr66tMAePxzOLfjGNcX',
#        'id': '6pmxr66tMAePxzOLfjGNcX',
#        'name': 'Beirut',
#        'type': 'artist',
#        'uri': 'spotify:artist:6pmxr66tMAePxzOLfjGNcX'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2CPgjTvNbPhOZndnvSXbfX'},
#      'href': 'https://api.spotify.com/v1/albums/2CPgjTvNbPhOZndnvSXbfX',
#      'id': '2CPgjTvNbPhOZndnvSXbfX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273661c404c96cc197faf8ec9d7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02661c404c96cc197faf8ec9d7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851661c404c96cc197faf8ec9d7',
#        'width': 64}],
#      'name': 'Elephant Gun',
#      'release_date': '2007-06-25',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:2CPgjTvNbPhOZndnvSXbfX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6pmxr66tMAePxzOLfjGNcX'},
#       'href': 'https://api.spotify.com/v1/artists/6pmxr66tMAePxzOLfjGNcX',
#       'id': '6pmxr66tMAePxzOLfjGNcX',
#       'name': 'Beirut',
#       'type': 'artist',
#       'uri': 'spotify:artist:6pmxr66tMAePxzOLfjGNcX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 348893,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCPT0600053'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0MtVmhAx6CxNuxFIUc6Mj9'},
#     'href': 'https://api.spotify.com/v1/tracks/0MtVmhAx6CxNuxFIUc6Mj9',
#     'id': '0MtVmhAx6CxNuxFIUc6Mj9',
#     'is_local': False,
#     'name': 'Elephant Gun',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/93f46a100e2df8c0770c8c458d22422dee156b32?cid=d151bde53dbd4ba0a64a51af0beb8ba1',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0MtVmhAx6CxNuxFIUc6Mj9'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-11-19T12:55:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#     'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#     'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#     'type': 'user',
#     'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cCUtGK9sDU2EoElnk0GNB'},
#        'href': 'https://api.spotify.com/v1/artists/2cCUtGK9sDU2EoElnk0GNB',
#        'id': '2cCUtGK9sDU2EoElnk0GNB',
#        'name': 'The National',
#        'type': 'artist',
#        'uri': 'spotify:artist:2cCUtGK9sDU2EoElnk0GNB'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2pG7mDkQhia2OyGE6fbkmJ'},
#      'href': 'https://api.spotify.com/v1/albums/2pG7mDkQhia2OyGE6fbkmJ',
#      'id': '2pG7mDkQhia2OyGE6fbkmJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273026f3ccb0e906a5032330752',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02026f3ccb0e906a5032330752',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851026f3ccb0e906a5032330752',
#        'width': 64}],
#      'name': 'Boxer',
#      'release_date': '2007-05-21',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2pG7mDkQhia2OyGE6fbkmJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cCUtGK9sDU2EoElnk0GNB'},
#       'href': 'https://api.spotify.com/v1/artists/2cCUtGK9sDU2EoElnk0GNB',
#       'id': '2cCUtGK9sDU2EoElnk0GNB',
#       'name': 'The National',
#       'type': 'artist',
#       'uri': 'spotify:artist:2cCUtGK9sDU2EoElnk0GNB'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 205040,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAZP0700003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6aUAF8JOd8zEl41B6I18xL'},
#     'href': 'https://api.spotify.com/v1/tracks/6aUAF8JOd8zEl41B6I18xL',
#     'id': '6aUAF8JOd8zEl41B6I18xL',
#     'is_local': False,
#     'name': 'Fake Empire',
#     'popularity': 4,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6aUAF8JOd8zEl41B6I18xL'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-12-13T16:08:52Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#     'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#     'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#     'type': 'user',
#     'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BwypqKeCj1DVIoEFwoz3S'},
#        'href': 'https://api.spotify.com/v1/artists/3BwypqKeCj1DVIoEFwoz3S',
#        'id': '3BwypqKeCj1DVIoEFwoz3S',
#        'name': 'Phill Veras',
#        'type': 'artist',
#        'uri': 'spotify:artist:3BwypqKeCj1DVIoEFwoz3S'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2PYLkcrVVEXiTVi0hdYAvm'},
#      'href': 'https://api.spotify.com/v1/albums/2PYLkcrVVEXiTVi0hdYAvm',
#      'id': '2PYLkcrVVEXiTVi0hdYAvm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27365c8eea4c39f9c0ae463ef07',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0265c8eea4c39f9c0ae463ef07',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485165c8eea4c39f9c0ae463ef07',
#        'width': 64}],
#      'name': 'Carpete',
#      'release_date': '2014-08-20',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:2PYLkcrVVEXiTVi0hdYAvm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BwypqKeCj1DVIoEFwoz3S'},
#       'href': 'https://api.spotify.com/v1/artists/3BwypqKeCj1DVIoEFwoz3S',
#       'id': '3BwypqKeCj1DVIoEFwoz3S',
#       'name': 'Phill Veras',
#       'type': 'artist',
#       'uri': 'spotify:artist:3BwypqKeCj1DVIoEFwoz3S'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 248480,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'BRYGD1400001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2vGvPQNnyybJmiqpr1HiKX'},
#     'href': 'https://api.spotify.com/v1/tracks/2vGvPQNnyybJmiqpr1HiKX',
#     'id': '2vGvPQNnyybJmiqpr1HiKX',
#     'is_local': False,
#     'name': 'Sorriso ao Sono',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2c3a52b90e2cab90c8627271cd271e1937948e4d?cid=d151bde53dbd4ba0a64a51af0beb8ba1',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2vGvPQNnyybJmiqpr1HiKX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-03-30T23:52:33Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#     'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#     'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#     'type': 'user',
#     'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3gd8FJtBJtkRxdfbTu19U2'},
#        'href': 'https://api.spotify.com/v1/artists/3gd8FJtBJtkRxdfbTu19U2',
#        'id': '3gd8FJtBJtkRxdfbTu19U2',
#        'name': 'Mumford & Sons',
#        'type': 'artist',
#        'uri': 'spotify:artist:3gd8FJtBJtkRxdfbTu19U2'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/64hKb8U28ebT5iDzcTrOsc'},
#      'href': 'https://api.spotify.com/v1/albums/64hKb8U28ebT5iDzcTrOsc',
#      'id': '64hKb8U28ebT5iDzcTrOsc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d6735b754406b20aac362222',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d6735b754406b20aac362222',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d6735b754406b20aac362222',
#        'width': 64}],
#      'name': 'Babel',
#      'release_date': '2012-09-21',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:64hKb8U28ebT5iDzcTrOsc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3gd8FJtBJtkRxdfbTu19U2'},
#       'href': 'https://api.spotify.com/v1/artists/3gd8FJtBJtkRxdfbTu19U2',
#       'id': '3gd8FJtBJtkRxdfbTu19U2',
#       'name': 'Mumford & Sons',
#       'type': 'artist',
#       'uri': 'spotify:artist:3gd8FJtBJtkRxdfbTu19U2'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 276720,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71204769'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1PuLHwFZoh5qYK89I5YBdZ'},
#     'href': 'https://api.spotify.com/v1/tracks/1PuLHwFZoh5qYK89I5YBdZ',
#     'id': '1PuLHwFZoh5qYK89I5YBdZ',
#     'is_local': False,
#     'name': 'I Will Wait',
#     'popularity': 1,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1PuLHwFZoh5qYK89I5YBdZ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-04-03T11:31:34Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#     'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#     'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#     'type': 'user',
#     'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54Bjxn26WsjfslQbNVtSCm'},
#        'href': 'https://api.spotify.com/v1/artists/54Bjxn26WsjfslQbNVtSCm',
#        'id': '54Bjxn26WsjfslQbNVtSCm',
#        'name': 'The Get Up Kids',
#        'type': 'artist',
#        'uri': 'spotify:artist:54Bjxn26WsjfslQbNVtSCm'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1CWMQ6KyikcMpkRpeKsXc3'},
#      'href': 'https://api.spotify.com/v1/albums/1CWMQ6KyikcMpkRpeKsXc3',
#      'id': '1CWMQ6KyikcMpkRpeKsXc3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734d9b9d9dbbaac219ab3f2c8b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024d9b9d9dbbaac219ab3f2c8b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514d9b9d9dbbaac219ab3f2c8b',
#        'width': 64}],
#      'name': 'Something To Write Home About',
#      'release_date': '1999-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:1CWMQ6KyikcMpkRpeKsXc3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54Bjxn26WsjfslQbNVtSCm'},
#       'href': 'https://api.spotify.com/v1/artists/54Bjxn26WsjfslQbNVtSCm',
#       'id': '54Bjxn26WsjfslQbNVtSCm',
#       'name': 'The Get Up Kids',
#       'type': 'artist',
#       'uri': 'spotify:artist:54Bjxn26WsjfslQbNVtSCm'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 226573,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USVR90334005'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0XqvweqwDQluyCKyK25XqC'},
#     'href': 'https://api.spotify.com/v1/tracks/0XqvweqwDQluyCKyK25XqC',
#     'id': '0XqvweqwDQluyCKyK25XqC',
#     'is_local': False,
#     'name': 'Out Of Reach',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0XqvweqwDQluyCKyK25XqC'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-04-03T11:31:40Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#     'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#     'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#     'type': 'user',
#     'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/35s58BRTGAEWztPo9WqCIs'},
#      'href': 'https://api.spotify.com/v1/albums/35s58BRTGAEWztPo9WqCIs',
#      'id': '35s58BRTGAEWztPo9WqCIs',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e2e352d89826aef6dbd5ff8f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e2e352d89826aef6dbd5ff8f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e2e352d89826aef6dbd5ff8f',
#        'width': 64}],
#      'name': 'Spider-Man: Into the Spider-Verse (Soundtrack From & Inspired by the Motion Picture)',
#      'release_date': '2018-12-14',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:35s58BRTGAEWztPo9WqCIs'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#       'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#       'id': '246dkjvS1zLTtiykXe5h60',
#       'name': 'Post Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1zNqQNIdeOUZHb8zbZRFMX'},
#       'href': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX',
#       'id': '1zNqQNIdeOUZHb8zbZRFMX',
#       'name': 'Swae Lee',
#       'type': 'artist',
#       'uri': 'spotify:artist:1zNqQNIdeOUZHb8zbZRFMX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 158040,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71814888'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3KkXRkHbMCARz0aVfEt68P'},
#     'href': 'https://api.spotify.com/v1/tracks/3KkXRkHbMCARz0aVfEt68P',
#     'id': '3KkXRkHbMCARz0aVfEt68P',
#     'is_local': False,
#     'name': 'Sunflower - Spider-Man: Into the Spider-Verse',
#     'popularity': 83,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3KkXRkHbMCARz0aVfEt68P'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-04-05T11:45:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#     'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#     'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#     'type': 'user',
#     'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26FGaBmX3yqXeFp3rTPWyp'},
#        'href': 'https://api.spotify.com/v1/artists/26FGaBmX3yqXeFp3rTPWyp',
#        'id': '26FGaBmX3yqXeFp3rTPWyp',
#        'name': 'Phillip Long',
#        'type': 'artist',
#        'uri': 'spotify:artist:26FGaBmX3yqXeFp3rTPWyp'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0dkLSE7IFxwm5QRtKQSjtI'},
#      'href': 'https://api.spotify.com/v1/albums/0dkLSE7IFxwm5QRtKQSjtI',
#      'id': '0dkLSE7IFxwm5QRtKQSjtI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f81b9443044e21ef0cfc9bf2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f81b9443044e21ef0cfc9bf2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f81b9443044e21ef0cfc9bf2',
#        'width': 64}],
#      'name': 'Gratitude',
#      'release_date': '2013-06-07',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0dkLSE7IFxwm5QRtKQSjtI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26FGaBmX3yqXeFp3rTPWyp'},
#       'href': 'https://api.spotify.com/v1/artists/26FGaBmX3yqXeFp3rTPWyp',
#       'id': '26FGaBmX3yqXeFp3rTPWyp',
#       'name': 'Phillip Long',
#       'type': 'artist',
#       'uri': 'spotify:artist:26FGaBmX3yqXeFp3rTPWyp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 206960,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'BXEE61400065'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5m9bm8tBxyhvKv41tMAdnv'},
#     'href': 'https://api.spotify.com/v1/tracks/5m9bm8tBxyhvKv41tMAdnv',
#     'id': '5m9bm8tBxyhvKv41tMAdnv',
#     'is_local': False,
#     'name': 'Want Someone to Remember Me',
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/07003ccb7f154568ea5d7508e2a0d636c1aa04de?cid=d151bde53dbd4ba0a64a51af0beb8ba1',
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:5m9bm8tBxyhvKv41tMAdnv'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-04-05T11:55:32Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#     'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#     'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#     'type': 'user',
#     'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3wWtfT7S2uVJJ3hGZlOLkZ'},
#        'href': 'https://api.spotify.com/v1/artists/3wWtfT7S2uVJJ3hGZlOLkZ',
#        'id': '3wWtfT7S2uVJJ3hGZlOLkZ',
#        'name': 'Judah & the Lion',
#        'type': 'artist',
#        'uri': 'spotify:artist:3wWtfT7S2uVJJ3hGZlOLkZ'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5fpYoh1ma26Fsr2XJB21Cp'},
#      'href': 'https://api.spotify.com/v1/albums/5fpYoh1ma26Fsr2XJB21Cp',
#      'id': '5fpYoh1ma26Fsr2XJB21Cp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27370a6ffc667e252798a908797',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0270a6ffc667e252798a908797',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485170a6ffc667e252798a908797',
#        'width': 64}],
#      'name': 'Over my head',
#      'release_date': '2019-01-11',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5fpYoh1ma26Fsr2XJB21Cp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3wWtfT7S2uVJJ3hGZlOLkZ'},
#       'href': 'https://api.spotify.com/v1/artists/3wWtfT7S2uVJJ3hGZlOLkZ',
#       'id': '3wWtfT7S2uVJJ3hGZlOLkZ',
#       'name': 'Judah & the Lion',
#       'type': 'artist',
#       'uri': 'spotify:artist:3wWtfT7S2uVJJ3hGZlOLkZ'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 195863,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMGSG1800003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6r5tlCMur8Vngv3n0DzOFl'},
#     'href': 'https://api.spotify.com/v1/tracks/6r5tlCMur8Vngv3n0DzOFl',
#     'id': '6r5tlCMur8Vngv3n0DzOFl',
#     'is_local': False,
#     'name': 'Over my head',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6r5tlCMur8Vngv3n0DzOFl'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-04-06T17:42:21Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#     'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#     'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#     'type': 'user',
#     'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JSc53B5cQ31m0xTB7JFpG'},
#        'href': 'https://api.spotify.com/v1/artists/2JSc53B5cQ31m0xTB7JFpG',
#        'id': '2JSc53B5cQ31m0xTB7JFpG',
#        'name': 'Rogue Wave',
#        'type': 'artist',
#        'uri': 'spotify:artist:2JSc53B5cQ31m0xTB7JFpG'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1EYKQBjyYJr8zu9CHxgeI2'},
#      'href': 'https://api.spotify.com/v1/albums/1EYKQBjyYJr8zu9CHxgeI2',
#      'id': '1EYKQBjyYJr8zu9CHxgeI2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273630655c8205b1c86d917bc52',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02630655c8205b1c86d917bc52',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851630655c8205b1c86d917bc52',
#        'width': 64}],
#      'name': 'Eyes',
#      'release_date': '2006-02-12',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1EYKQBjyYJr8zu9CHxgeI2'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JSc53B5cQ31m0xTB7JFpG'},
#       'href': 'https://api.spotify.com/v1/artists/2JSc53B5cQ31m0xTB7JFpG',
#       'id': '2JSc53B5cQ31m0xTB7JFpG',
#       'name': 'Rogue Wave',
#       'type': 'artist',
#       'uri': 'spotify:artist:2JSc53B5cQ31m0xTB7JFpG'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 148866,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSUB0671301'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3HQdwlovzULm18PjvlA5wz'},
#     'href': 'https://api.spotify.com/v1/tracks/3HQdwlovzULm18PjvlA5wz',
#     'id': '3HQdwlovzULm18PjvlA5wz',
#     'is_local': False,
#     'name': 'Eyes',
#     'popularity': 1,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3HQdwlovzULm18PjvlA5wz'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-04-06T18:04:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#     'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#     'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#     'type': 'user',
#     'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Li0eIWeMeWcOOWpImcG9H'},
#        'href': 'https://api.spotify.com/v1/artists/1Li0eIWeMeWcOOWpImcG9H',
#        'id': '1Li0eIWeMeWcOOWpImcG9H',
#        'name': 'Albert Hammond Jr',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Li0eIWeMeWcOOWpImcG9H'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BZ',
#       'CA',
#       'CH',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
# ...
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5LBWG5i3CXBQtGrgJnxk27'},
#      'href': 'https://api.spotify.com/v1/albums/5LBWG5i3CXBQtGrgJnxk27',
#      'id': '5LBWG5i3CXBQtGrgJnxk27',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27389f4b2f72ffa95acb221a64a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0289f4b2f72ffa95acb221a64a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485189f4b2f72ffa95acb221a64a',
#        'width': 64}],
#      'name': 'Lvr Boy',
#      'release_date': '2018-04-23',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5LBWG5i3CXBQtGrgJnxk27'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1vkWdqcabQ1swciXipkLBj'},
#       'href': 'https://api.spotify.com/v1/artists/1vkWdqcabQ1swciXipkLBj',
#       'id': '1vkWdqcabQ1swciXipkLBj',
#       'name': 'awfultune',
#       'type': 'artist',
#       'uri': 'spotify:artist:1vkWdqcabQ1swciXipkLBj'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 295751,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE5BU1818696'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Py8QOQ4I1286xM9KncPQ4'},
#     'href': 'https://api.spotify.com/v1/tracks/6Py8QOQ4I1286xM9KncPQ4',
#     'id': '6Py8QOQ4I1286xM9KncPQ4',
#     'is_local': False,
#     'name': 'Lvr Boy',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f6d9c82a228a0f93d913c1373e8319e7b97d387e?cid=d151bde53dbd4ba0a64a51af0beb8ba1',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6Py8QOQ4I1286xM9KncPQ4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-06-29T19:31:40Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#     'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#     'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#     'type': 'user',
#     'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Bo5UEoUopq42HZX3apU1w'},
#        'href': 'https://api.spotify.com/v1/artists/6Bo5UEoUopq42HZX3apU1w',
#        'id': '6Bo5UEoUopq42HZX3apU1w',
#        'name': 'Philip Brooks',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Bo5UEoUopq42HZX3apU1w'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1sl4k7N8YHq8IiQkyhbNhy'},
#      'href': 'https://api.spotify.com/v1/albums/1sl4k7N8YHq8IiQkyhbNhy',
#      'id': '1sl4k7N8YHq8IiQkyhbNhy',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27322ad92dfd3e91df7e36517c8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0222ad92dfd3e91df7e36517c8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485122ad92dfd3e91df7e36517c8',
#        'width': 64}],
#      'name': "Honey Let's Just Drive",
#      'release_date': '2018',
#      'release_date_precision': 'year',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1sl4k7N8YHq8IiQkyhbNhy'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Bo5UEoUopq42HZX3apU1w'},
#       'href': 'https://api.spotify.com/v1/artists/6Bo5UEoUopq42HZX3apU1w',
#       'id': '6Bo5UEoUopq42HZX3apU1w',
#       'name': 'Philip Brooks',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Bo5UEoUopq42HZX3apU1w'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 211285,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZ22B1933124'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/06OLH1cjQrSuWrqg7FXTD3'},
#     'href': 'https://api.spotify.com/v1/tracks/06OLH1cjQrSuWrqg7FXTD3',
#     'id': '06OLH1cjQrSuWrqg7FXTD3',
#     'is_local': False,
#     'name': "Honey Let's Just Drive",
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:06OLH1cjQrSuWrqg7FXTD3'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-07-10T14:14:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#     'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#     'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#     'type': 'user',
#     'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6AyATGg7mDgBlZ4N5uNog0'},
#        'href': 'https://api.spotify.com/v1/artists/6AyATGg7mDgBlZ4N5uNog0',
#        'id': '6AyATGg7mDgBlZ4N5uNog0',
#        'name': 'SYML',
#        'type': 'artist',
#        'uri': 'spotify:artist:6AyATGg7mDgBlZ4N5uNog0'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1aUoV342m2QNWmodRApC5s'},
#      'href': 'https://api.spotify.com/v1/albums/1aUoV342m2QNWmodRApC5s',
#      'id': '1aUoV342m2QNWmodRApC5s',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27315473e3d52e539bcbdb50ac0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0215473e3d52e539bcbdb50ac0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485115473e3d52e539bcbdb50ac0',
#        'width': 64}],
#      'name': "Where's My Love",
#      'release_date': '2017-07-07',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:1aUoV342m2QNWmodRApC5s'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6AyATGg7mDgBlZ4N5uNog0'},
#       'href': 'https://api.spotify.com/v1/artists/6AyATGg7mDgBlZ4N5uNog0',
#       'id': '6AyATGg7mDgBlZ4N5uNog0',
#       'name': 'SYML',
#       'type': 'artist',
#       'uri': 'spotify:artist:6AyATGg7mDgBlZ4N5uNog0'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 239880,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'CAN111600624'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/51Yy4jTMPlq0Qwnn53id64'},
#     'href': 'https://api.spotify.com/v1/tracks/51Yy4jTMPlq0Qwnn53id64',
#     'id': '51Yy4jTMPlq0Qwnn53id64',
#     'is_local': False,
#     'name': "Where's My Love - Acoustic",
#     'popularity': 1,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:51Yy4jTMPlq0Qwnn53id64'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-07-19T12:15:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#     'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#     'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#     'type': 'user',
#     'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5o206eFLx38glA2bb4zqIU'},
#        'href': 'https://api.spotify.com/v1/artists/5o206eFLx38glA2bb4zqIU',
#        'id': '5o206eFLx38glA2bb4zqIU',
#        'name': 'Bright Eyes',
#        'type': 'artist',
#        'uri': 'spotify:artist:5o206eFLx38glA2bb4zqIU'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5msfCyqu8fJYqDDV6OrXTg'},
#      'href': 'https://api.spotify.com/v1/albums/5msfCyqu8fJYqDDV6OrXTg',
#      'id': '5msfCyqu8fJYqDDV6OrXTg',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d5edf0a2f87a3a6ce19c48e7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d5edf0a2f87a3a6ce19c48e7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d5edf0a2f87a3a6ce19c48e7',
#        'width': 64}],
#      'name': "I'm Wide Awake, It's Morning",
#      'release_date': '2005-01-25',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5msfCyqu8fJYqDDV6OrXTg'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5o206eFLx38glA2bb4zqIU'},
#       'href': 'https://api.spotify.com/v1/artists/5o206eFLx38glA2bb4zqIU',
#       'id': '5o206eFLx38glA2bb4zqIU',
#       'name': 'Bright Eyes',
#       'type': 'artist',
#       'uri': 'spotify:artist:5o206eFLx38glA2bb4zqIU'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 271666,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'US2U60507204'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4PMvRfhHAx5j6Bb3XsFLoq'},
#     'href': 'https://api.spotify.com/v1/tracks/4PMvRfhHAx5j6Bb3XsFLoq',
#     'id': '4PMvRfhHAx5j6Bb3XsFLoq',
#     'is_local': False,
#     'name': 'Lua',
#     'popularity': 55,
#     'preview_url': None,
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4PMvRfhHAx5j6Bb3XsFLoq'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2019-07-19T22:40:43Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#     'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#     'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#     'type': 'user',
#     'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/46CitWgnWrvF9t70C2p1Me'},
#        'href': 'https://api.spotify.com/v1/artists/46CitWgnWrvF9t70C2p1Me',
#        'id': '46CitWgnWrvF9t70C2p1Me',
#        'name': 'Daughter',
#        'type': 'artist',
#        'uri': 'spotify:artist:46CitWgnWrvF9t70C2p1Me'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6E76aabodIl5DW5BTEZPHG'},
#      'href': 'https://api.spotify.com/v1/albums/6E76aabodIl5DW5BTEZPHG',
#      'id': '6E76aabodIl5DW5BTEZPHG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734441fbfc0e9acd17edb29004',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024441fbfc0e9acd17edb29004',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514441fbfc0e9acd17edb29004',
#        'width': 64}],
#      'name': 'If You Leave',
#      'release_date': '2013-03-18',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:6E76aabodIl5DW5BTEZPHG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/46CitWgnWrvF9t70C2p1Me'},
#       'href': 'https://api.spotify.com/v1/artists/46CitWgnWrvF9t70C2p1Me',
#       'id': '46CitWgnWrvF9t70C2p1Me',
#       'name': 'Daughter',
#       'type': 'artist',
#       'uri': 'spotify:artist:46CitWgnWrvF9t70C2p1Me'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 253013,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAFL1200314'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6tqzOYuE3lrNVPDgtF3MjM'},
#     'href': 'https://api.spotify.com/v1/tracks/6tqzOYuE3lrNVPDgtF3MjM',
#     'id': '6tqzOYuE3lrNVPDgtF3MjM',
#     'is_local': False,
#     'name': 'Youth',
#     'popularity': 11,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6tqzOYuE3lrNVPDgtF3MjM'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/12Wbv8sIx84T5uh6iOoJ7V/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 202}

# %%
playlist["total"]
# Out:
# 202

# %%
len(playlist["items"])
# Out:
# 100

# %%
results = sp.user_playlist_tracks("spotify", "12Wbv8sIx84T5uh6iOoJ7V")
tracks = results['items']

while results['next']:
    results = sp.next(results)
    tracks.extend(results['items'])

# %%
results = sp.user_playlist_tracks("spotify", "12Wbv8sIx84T5uh6iOoJ7V")
tracks = results['items']

for oset in range(100,results['total'],100):
    results = sp.user_playlist_tracks("spotify", "12Wbv8sIx84T5uh6iOoJ7V", offset=oset)
    tracks += results['items']
len(tracks)
# Out:
# 202

# %%
list(range(100,results['total'],100))
# Out:
# [100, 200]

# %%
# It is limited to 100 tracks, we will have to fix it:

def get_playlist_tracks(username, playlist_id):
    
    results = sp.user_playlist_tracks(username, playlist_id)
    tracks = results['items']
    
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    
    return tracks

tracks = get_playlist_tracks("spotify", "12Wbv8sIx84T5uh6iOoJ7V")

# %%
tracks#[0]['track']#['artists']#.keys()#['name']
# Out:
# [{'added_at': '2018-07-19T13:11:46Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#    'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#    'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#    'type': 'user',
#    'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2HubQ6TEbD7HknCNrBsqhR'},
#       'href': 'https://api.spotify.com/v1/artists/2HubQ6TEbD7HknCNrBsqhR',
#       'id': '2HubQ6TEbD7HknCNrBsqhR',
#       'name': 'Marcelo Camelo',
#       'type': 'artist',
#       'uri': 'spotify:artist:2HubQ6TEbD7HknCNrBsqhR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1NP7PX0MQPH6pLHr2R8e9K'},
#     'href': 'https://api.spotify.com/v1/albums/1NP7PX0MQPH6pLHr2R8e9K',
#     'id': '1NP7PX0MQPH6pLHr2R8e9K',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739567789633ace59e4e2f2a9d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029567789633ace59e4e2f2a9d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519567789633ace59e4e2f2a9d',
#       'width': 64}],
#     'name': 'Toque Dela',
#     'release_date': '2011-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:1NP7PX0MQPH6pLHr2R8e9K'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2HubQ6TEbD7HknCNrBsqhR'},
#      'href': 'https://api.spotify.com/v1/artists/2HubQ6TEbD7HknCNrBsqhR',
#      'id': '2HubQ6TEbD7HknCNrBsqhR',
#      'name': 'Marcelo Camelo',
#      'type': 'artist',
#      'uri': 'spotify:artist:2HubQ6TEbD7HknCNrBsqhR'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GD',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 323280,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'BRZE51100005'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0A0eOcimSNRs2EQQlH7FFJ'},
#    'href': 'https://api.spotify.com/v1/tracks/0A0eOcimSNRs2EQQlH7FFJ',
#    'id': '0A0eOcimSNRs2EQQlH7FFJ',
#    'is_local': False,
#    'name': 'Três Dias',
#    'popularity': 27,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:0A0eOcimSNRs2EQQlH7FFJ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2018-07-20T17:29:03Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#    'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#    'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#    'type': 'user',
#    'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6pmxr66tMAePxzOLfjGNcX'},
#       'href': 'https://api.spotify.com/v1/artists/6pmxr66tMAePxzOLfjGNcX',
#       'id': '6pmxr66tMAePxzOLfjGNcX',
#       'name': 'Beirut',
#       'type': 'artist',
#       'uri': 'spotify:artist:6pmxr66tMAePxzOLfjGNcX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2CPgjTvNbPhOZndnvSXbfX'},
#     'href': 'https://api.spotify.com/v1/albums/2CPgjTvNbPhOZndnvSXbfX',
#     'id': '2CPgjTvNbPhOZndnvSXbfX',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273661c404c96cc197faf8ec9d7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02661c404c96cc197faf8ec9d7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851661c404c96cc197faf8ec9d7',
#       'width': 64}],
#     'name': 'Elephant Gun',
#     'release_date': '2007-06-25',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:2CPgjTvNbPhOZndnvSXbfX'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6pmxr66tMAePxzOLfjGNcX'},
#      'href': 'https://api.spotify.com/v1/artists/6pmxr66tMAePxzOLfjGNcX',
#      'id': '6pmxr66tMAePxzOLfjGNcX',
#      'name': 'Beirut',
#      'type': 'artist',
#      'uri': 'spotify:artist:6pmxr66tMAePxzOLfjGNcX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 348893,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCPT0600053'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0MtVmhAx6CxNuxFIUc6Mj9'},
#    'href': 'https://api.spotify.com/v1/tracks/0MtVmhAx6CxNuxFIUc6Mj9',
#    'id': '0MtVmhAx6CxNuxFIUc6Mj9',
#    'is_local': False,
#    'name': 'Elephant Gun',
#    'popularity': 60,
#    'preview_url': 'https://p.scdn.co/mp3-preview/93f46a100e2df8c0770c8c458d22422dee156b32?cid=d151bde53dbd4ba0a64a51af0beb8ba1',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0MtVmhAx6CxNuxFIUc6Mj9'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2018-11-19T12:55:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#    'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#    'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#    'type': 'user',
#    'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cCUtGK9sDU2EoElnk0GNB'},
#       'href': 'https://api.spotify.com/v1/artists/2cCUtGK9sDU2EoElnk0GNB',
#       'id': '2cCUtGK9sDU2EoElnk0GNB',
#       'name': 'The National',
#       'type': 'artist',
#       'uri': 'spotify:artist:2cCUtGK9sDU2EoElnk0GNB'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2pG7mDkQhia2OyGE6fbkmJ'},
#     'href': 'https://api.spotify.com/v1/albums/2pG7mDkQhia2OyGE6fbkmJ',
#     'id': '2pG7mDkQhia2OyGE6fbkmJ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273026f3ccb0e906a5032330752',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02026f3ccb0e906a5032330752',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851026f3ccb0e906a5032330752',
#       'width': 64}],
#     'name': 'Boxer',
#     'release_date': '2007-05-21',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2pG7mDkQhia2OyGE6fbkmJ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2cCUtGK9sDU2EoElnk0GNB'},
#      'href': 'https://api.spotify.com/v1/artists/2cCUtGK9sDU2EoElnk0GNB',
#      'id': '2cCUtGK9sDU2EoElnk0GNB',
#      'name': 'The National',
#      'type': 'artist',
#      'uri': 'spotify:artist:2cCUtGK9sDU2EoElnk0GNB'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 205040,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAZP0700003'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6aUAF8JOd8zEl41B6I18xL'},
#    'href': 'https://api.spotify.com/v1/tracks/6aUAF8JOd8zEl41B6I18xL',
#    'id': '6aUAF8JOd8zEl41B6I18xL',
#    'is_local': False,
#    'name': 'Fake Empire',
#    'popularity': 4,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6aUAF8JOd8zEl41B6I18xL'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2018-12-13T16:08:52Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#    'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#    'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#    'type': 'user',
#    'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BwypqKeCj1DVIoEFwoz3S'},
#       'href': 'https://api.spotify.com/v1/artists/3BwypqKeCj1DVIoEFwoz3S',
#       'id': '3BwypqKeCj1DVIoEFwoz3S',
#       'name': 'Phill Veras',
#       'type': 'artist',
#       'uri': 'spotify:artist:3BwypqKeCj1DVIoEFwoz3S'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2PYLkcrVVEXiTVi0hdYAvm'},
#     'href': 'https://api.spotify.com/v1/albums/2PYLkcrVVEXiTVi0hdYAvm',
#     'id': '2PYLkcrVVEXiTVi0hdYAvm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27365c8eea4c39f9c0ae463ef07',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0265c8eea4c39f9c0ae463ef07',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485165c8eea4c39f9c0ae463ef07',
#       'width': 64}],
#     'name': 'Carpete',
#     'release_date': '2014-08-20',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:2PYLkcrVVEXiTVi0hdYAvm'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BwypqKeCj1DVIoEFwoz3S'},
#      'href': 'https://api.spotify.com/v1/artists/3BwypqKeCj1DVIoEFwoz3S',
#      'id': '3BwypqKeCj1DVIoEFwoz3S',
#      'name': 'Phill Veras',
#      'type': 'artist',
#      'uri': 'spotify:artist:3BwypqKeCj1DVIoEFwoz3S'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 248480,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'BRYGD1400001'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2vGvPQNnyybJmiqpr1HiKX'},
#    'href': 'https://api.spotify.com/v1/tracks/2vGvPQNnyybJmiqpr1HiKX',
#    'id': '2vGvPQNnyybJmiqpr1HiKX',
#    'is_local': False,
#    'name': 'Sorriso ao Sono',
#    'popularity': 47,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2c3a52b90e2cab90c8627271cd271e1937948e4d?cid=d151bde53dbd4ba0a64a51af0beb8ba1',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2vGvPQNnyybJmiqpr1HiKX'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-03-30T23:52:33Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#    'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#    'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#    'type': 'user',
#    'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3gd8FJtBJtkRxdfbTu19U2'},
#       'href': 'https://api.spotify.com/v1/artists/3gd8FJtBJtkRxdfbTu19U2',
#       'id': '3gd8FJtBJtkRxdfbTu19U2',
#       'name': 'Mumford & Sons',
#       'type': 'artist',
#       'uri': 'spotify:artist:3gd8FJtBJtkRxdfbTu19U2'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/64hKb8U28ebT5iDzcTrOsc'},
#     'href': 'https://api.spotify.com/v1/albums/64hKb8U28ebT5iDzcTrOsc',
#     'id': '64hKb8U28ebT5iDzcTrOsc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d6735b754406b20aac362222',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d6735b754406b20aac362222',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d6735b754406b20aac362222',
#       'width': 64}],
#     'name': 'Babel',
#     'release_date': '2012-09-21',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:64hKb8U28ebT5iDzcTrOsc'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3gd8FJtBJtkRxdfbTu19U2'},
#      'href': 'https://api.spotify.com/v1/artists/3gd8FJtBJtkRxdfbTu19U2',
#      'id': '3gd8FJtBJtkRxdfbTu19U2',
#      'name': 'Mumford & Sons',
#      'type': 'artist',
#      'uri': 'spotify:artist:3gd8FJtBJtkRxdfbTu19U2'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 276720,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM71204769'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1PuLHwFZoh5qYK89I5YBdZ'},
#    'href': 'https://api.spotify.com/v1/tracks/1PuLHwFZoh5qYK89I5YBdZ',
#    'id': '1PuLHwFZoh5qYK89I5YBdZ',
#    'is_local': False,
#    'name': 'I Will Wait',
#    'popularity': 1,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:1PuLHwFZoh5qYK89I5YBdZ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-04-03T11:31:34Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#    'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#    'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#    'type': 'user',
#    'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54Bjxn26WsjfslQbNVtSCm'},
#       'href': 'https://api.spotify.com/v1/artists/54Bjxn26WsjfslQbNVtSCm',
#       'id': '54Bjxn26WsjfslQbNVtSCm',
#       'name': 'The Get Up Kids',
#       'type': 'artist',
#       'uri': 'spotify:artist:54Bjxn26WsjfslQbNVtSCm'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1CWMQ6KyikcMpkRpeKsXc3'},
#     'href': 'https://api.spotify.com/v1/albums/1CWMQ6KyikcMpkRpeKsXc3',
#     'id': '1CWMQ6KyikcMpkRpeKsXc3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734d9b9d9dbbaac219ab3f2c8b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024d9b9d9dbbaac219ab3f2c8b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514d9b9d9dbbaac219ab3f2c8b',
#       'width': 64}],
#     'name': 'Something To Write Home About',
#     'release_date': '1999-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:1CWMQ6KyikcMpkRpeKsXc3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/54Bjxn26WsjfslQbNVtSCm'},
#      'href': 'https://api.spotify.com/v1/artists/54Bjxn26WsjfslQbNVtSCm',
#      'id': '54Bjxn26WsjfslQbNVtSCm',
#      'name': 'The Get Up Kids',
#      'type': 'artist',
#      'uri': 'spotify:artist:54Bjxn26WsjfslQbNVtSCm'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 226573,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USVR90334005'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0XqvweqwDQluyCKyK25XqC'},
#    'href': 'https://api.spotify.com/v1/tracks/0XqvweqwDQluyCKyK25XqC',
#    'id': '0XqvweqwDQluyCKyK25XqC',
#    'is_local': False,
#    'name': 'Out Of Reach',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:0XqvweqwDQluyCKyK25XqC'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-04-03T11:31:40Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#    'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#    'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#    'type': 'user',
#    'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/35s58BRTGAEWztPo9WqCIs'},
#     'href': 'https://api.spotify.com/v1/albums/35s58BRTGAEWztPo9WqCIs',
#     'id': '35s58BRTGAEWztPo9WqCIs',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e2e352d89826aef6dbd5ff8f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e2e352d89826aef6dbd5ff8f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e2e352d89826aef6dbd5ff8f',
#       'width': 64}],
#     'name': 'Spider-Man: Into the Spider-Verse (Soundtrack From & Inspired by the Motion Picture)',
#     'release_date': '2018-12-14',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:35s58BRTGAEWztPo9WqCIs'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/246dkjvS1zLTtiykXe5h60'},
#      'href': 'https://api.spotify.com/v1/artists/246dkjvS1zLTtiykXe5h60',
#      'id': '246dkjvS1zLTtiykXe5h60',
#      'name': 'Post Malone',
#      'type': 'artist',
#      'uri': 'spotify:artist:246dkjvS1zLTtiykXe5h60'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1zNqQNIdeOUZHb8zbZRFMX'},
#      'href': 'https://api.spotify.com/v1/artists/1zNqQNIdeOUZHb8zbZRFMX',
#      'id': '1zNqQNIdeOUZHb8zbZRFMX',
#      'name': 'Swae Lee',
#      'type': 'artist',
#      'uri': 'spotify:artist:1zNqQNIdeOUZHb8zbZRFMX'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 158040,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM71814888'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3KkXRkHbMCARz0aVfEt68P'},
#    'href': 'https://api.spotify.com/v1/tracks/3KkXRkHbMCARz0aVfEt68P',
#    'id': '3KkXRkHbMCARz0aVfEt68P',
#    'is_local': False,
#    'name': 'Sunflower - Spider-Man: Into the Spider-Verse',
#    'popularity': 83,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:3KkXRkHbMCARz0aVfEt68P'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-04-05T11:45:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#    'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#    'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#    'type': 'user',
#    'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26FGaBmX3yqXeFp3rTPWyp'},
#       'href': 'https://api.spotify.com/v1/artists/26FGaBmX3yqXeFp3rTPWyp',
#       'id': '26FGaBmX3yqXeFp3rTPWyp',
#       'name': 'Phillip Long',
#       'type': 'artist',
#       'uri': 'spotify:artist:26FGaBmX3yqXeFp3rTPWyp'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0dkLSE7IFxwm5QRtKQSjtI'},
#     'href': 'https://api.spotify.com/v1/albums/0dkLSE7IFxwm5QRtKQSjtI',
#     'id': '0dkLSE7IFxwm5QRtKQSjtI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f81b9443044e21ef0cfc9bf2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f81b9443044e21ef0cfc9bf2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f81b9443044e21ef0cfc9bf2',
#       'width': 64}],
#     'name': 'Gratitude',
#     'release_date': '2013-06-07',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:0dkLSE7IFxwm5QRtKQSjtI'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26FGaBmX3yqXeFp3rTPWyp'},
#      'href': 'https://api.spotify.com/v1/artists/26FGaBmX3yqXeFp3rTPWyp',
#      'id': '26FGaBmX3yqXeFp3rTPWyp',
#      'name': 'Phillip Long',
#      'type': 'artist',
#      'uri': 'spotify:artist:26FGaBmX3yqXeFp3rTPWyp'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 206960,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'BXEE61400065'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5m9bm8tBxyhvKv41tMAdnv'},
#    'href': 'https://api.spotify.com/v1/tracks/5m9bm8tBxyhvKv41tMAdnv',
#    'id': '5m9bm8tBxyhvKv41tMAdnv',
#    'is_local': False,
#    'name': 'Want Someone to Remember Me',
#    'popularity': 33,
#    'preview_url': 'https://p.scdn.co/mp3-preview/07003ccb7f154568ea5d7508e2a0d636c1aa04de?cid=d151bde53dbd4ba0a64a51af0beb8ba1',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:5m9bm8tBxyhvKv41tMAdnv'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-04-05T11:55:32Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#    'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#    'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#    'type': 'user',
#    'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3wWtfT7S2uVJJ3hGZlOLkZ'},
#       'href': 'https://api.spotify.com/v1/artists/3wWtfT7S2uVJJ3hGZlOLkZ',
#       'id': '3wWtfT7S2uVJJ3hGZlOLkZ',
#       'name': 'Judah & the Lion',
#       'type': 'artist',
#       'uri': 'spotify:artist:3wWtfT7S2uVJJ3hGZlOLkZ'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5fpYoh1ma26Fsr2XJB21Cp'},
#     'href': 'https://api.spotify.com/v1/albums/5fpYoh1ma26Fsr2XJB21Cp',
#     'id': '5fpYoh1ma26Fsr2XJB21Cp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27370a6ffc667e252798a908797',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0270a6ffc667e252798a908797',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485170a6ffc667e252798a908797',
#       'width': 64}],
#     'name': 'Over my head',
#     'release_date': '2019-01-11',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:5fpYoh1ma26Fsr2XJB21Cp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3wWtfT7S2uVJJ3hGZlOLkZ'},
#      'href': 'https://api.spotify.com/v1/artists/3wWtfT7S2uVJJ3hGZlOLkZ',
#      'id': '3wWtfT7S2uVJJ3hGZlOLkZ',
#      'name': 'Judah & the Lion',
#      'type': 'artist',
#      'uri': 'spotify:artist:3wWtfT7S2uVJJ3hGZlOLkZ'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 195863,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMGSG1800003'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6r5tlCMur8Vngv3n0DzOFl'},
#    'href': 'https://api.spotify.com/v1/tracks/6r5tlCMur8Vngv3n0DzOFl',
#    'id': '6r5tlCMur8Vngv3n0DzOFl',
#    'is_local': False,
#    'name': 'Over my head',
#    'popularity': 0,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6r5tlCMur8Vngv3n0DzOFl'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-04-06T17:42:21Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#    'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#    'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#    'type': 'user',
#    'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JSc53B5cQ31m0xTB7JFpG'},
#       'href': 'https://api.spotify.com/v1/artists/2JSc53B5cQ31m0xTB7JFpG',
#       'id': '2JSc53B5cQ31m0xTB7JFpG',
#       'name': 'Rogue Wave',
#       'type': 'artist',
#       'uri': 'spotify:artist:2JSc53B5cQ31m0xTB7JFpG'}],
#     'available_markets': [],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1EYKQBjyYJr8zu9CHxgeI2'},
#     'href': 'https://api.spotify.com/v1/albums/1EYKQBjyYJr8zu9CHxgeI2',
#     'id': '1EYKQBjyYJr8zu9CHxgeI2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273630655c8205b1c86d917bc52',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02630655c8205b1c86d917bc52',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851630655c8205b1c86d917bc52',
#       'width': 64}],
#     'name': 'Eyes',
#     'release_date': '2006-02-12',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1EYKQBjyYJr8zu9CHxgeI2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2JSc53B5cQ31m0xTB7JFpG'},
#      'href': 'https://api.spotify.com/v1/artists/2JSc53B5cQ31m0xTB7JFpG',
#      'id': '2JSc53B5cQ31m0xTB7JFpG',
#      'name': 'Rogue Wave',
#      'type': 'artist',
#      'uri': 'spotify:artist:2JSc53B5cQ31m0xTB7JFpG'}],
#    'available_markets': [],
#    'disc_number': 1,
#    'duration_ms': 148866,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSUB0671301'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3HQdwlovzULm18PjvlA5wz'},
#    'href': 'https://api.spotify.com/v1/tracks/3HQdwlovzULm18PjvlA5wz',
#    'id': '3HQdwlovzULm18PjvlA5wz',
#    'is_local': False,
#    'name': 'Eyes',
#    'popularity': 1,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3HQdwlovzULm18PjvlA5wz'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-04-06T18:04:45Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#    'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#    'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#    'type': 'user',
#    'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Li0eIWeMeWcOOWpImcG9H'},
#       'href': 'https://api.spotify.com/v1/artists/1Li0eIWeMeWcOOWpImcG9H',
#       'id': '1Li0eIWeMeWcOOWpImcG9H',
#       'name': 'Albert Hammond Jr',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Li0eIWeMeWcOOWpImcG9H'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BZ',
#      'CA',
#      'CH',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'MG',
#      'MH',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'ZA',
#      'ZM'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1pJT6SArgRf1aQ5DCTxl7g'},
#     'href': 'https://api.spotify.com/v1/albums/1pJT6SArgRf1aQ5DCTxl7g',
#     'id': '1pJT6SArgRf1aQ5DCTxl7g',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736ac99a3e59c752a0fb13088f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026ac99a3e59c752a0fb13088f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516ac99a3e59c752a0fb13088f',
#       'width': 64}],
#     'name': 'Yours to Keep',
#     'release_date': '2006',
#     'release_date_precision': 'year',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:1pJT6SArgRf1aQ5DCTxl7g'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Li0eIWeMeWcOOWpImcG9H'},
#      'href': 'https://api.spotify.com/v1/artists/1Li0eIWeMeWcOOWpImcG9H',
#      'id': '1Li0eIWeMeWcOOWpImcG9H',
#      'name': 'Albert Hammond Jr',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Li0eIWeMeWcOOWpImcG9H'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BZ',
#     'CA',
#     'CH',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
# ...
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 184400,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'usl4r1937262'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/31Xlp8YDrHFNN54Y2F8fB8'},
#    'href': 'https://api.spotify.com/v1/tracks/31Xlp8YDrHFNN54Y2F8fB8',
#    'id': '31Xlp8YDrHFNN54Y2F8fB8',
#    'is_local': False,
#    'name': 'Manhorse',
#    'popularity': 36,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a1b9b0c5ac9ebedd5daf7b442afe1583850aa3d8?cid=d151bde53dbd4ba0a64a51af0beb8ba1',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:31Xlp8YDrHFNN54Y2F8fB8'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-02-09T14:31:58Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#    'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#    'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#    'type': 'user',
#    'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7K3zpFXBvPcvzhj7zlGJdO'},
#       'href': 'https://api.spotify.com/v1/artists/7K3zpFXBvPcvzhj7zlGJdO',
#       'id': '7K3zpFXBvPcvzhj7zlGJdO',
#       'name': 'Crystal Castles',
#       'type': 'artist',
#       'uri': 'spotify:artist:7K3zpFXBvPcvzhj7zlGJdO'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AM',
#      'AR',
#      'AT',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DM',
#      'DO',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GB',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LI',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MN',
#      'MO',
#      'MT',
#      'MU',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'SZ',
#      'TD',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'UG',
#      'US',
#      'UZ',
#      'VN',
#      'XK',
#      'ZA',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/37TeO5usN4vsGSfpg4dPNA'},
#     'href': 'https://api.spotify.com/v1/albums/37TeO5usN4vsGSfpg4dPNA',
#     'id': '37TeO5usN4vsGSfpg4dPNA',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735ac6226a668978bf43185e97',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025ac6226a668978bf43185e97',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515ac6226a668978bf43185e97',
#       'width': 64}],
#     'name': '(II)',
#     'release_date': '2011-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:37TeO5usN4vsGSfpg4dPNA'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7K3zpFXBvPcvzhj7zlGJdO'},
#      'href': 'https://api.spotify.com/v1/artists/7K3zpFXBvPcvzhj7zlGJdO',
#      'id': '7K3zpFXBvPcvzhj7zlGJdO',
#      'name': 'Crystal Castles',
#      'type': 'artist',
#      'uri': 'spotify:artist:7K3zpFXBvPcvzhj7zlGJdO'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6G7P2EzH5A36ujN9VPm4B0'},
#      'href': 'https://api.spotify.com/v1/artists/6G7P2EzH5A36ujN9VPm4B0',
#      'id': '6G7P2EzH5A36ujN9VPm4B0',
#      'name': 'Robert Smith',
#      'type': 'artist',
#      'uri': 'spotify:artist:6G7P2EzH5A36ujN9VPm4B0'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AM',
#     'AR',
#     'AT',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BW',
#     'BY',
#     'BZ',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DM',
#     'DO',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GB',
#     'GD',
#     'GH',
#     'GM',
#     'GN',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LI',
#     'LK',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MD',
#     'ME',
#     'MK',
#     'MN',
#     'MO',
#     'MT',
#     'MU',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PL',
#     'PT',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SV',
#     'SZ',
#     'TD',
#     'TH',
#     'TN',
#     'TR',
#     'TT',
#     'TW',
#     'UA',
#     'UG',
#     'US',
#     'UZ',
#     'VN',
#     'XK',
#     'ZA',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 226986,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM71029513'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/46Xnj8vZFwOZCE4aZNXlTf'},
#    'href': 'https://api.spotify.com/v1/tracks/46Xnj8vZFwOZCE4aZNXlTf',
#    'id': '46Xnj8vZFwOZCE4aZNXlTf',
#    'is_local': False,
#    'name': 'Not In Love - Radio Version',
#    'popularity': 61,
#    'preview_url': None,
#    'track': True,
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:46Xnj8vZFwOZCE4aZNXlTf'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-02-09T14:34:37Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#    'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#    'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#    'type': 'user',
#    'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2bDSLK8y2edA9n2TPbzv6h'},
#       'href': 'https://api.spotify.com/v1/artists/2bDSLK8y2edA9n2TPbzv6h',
#       'id': '2bDSLK8y2edA9n2TPbzv6h',
#       'name': 'The Little Ones',
#       'type': 'artist',
#       'uri': 'spotify:artist:2bDSLK8y2edA9n2TPbzv6h'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4cCKpuZ39qNKS5utpDDmOC'},
#     'href': 'https://api.spotify.com/v1/albums/4cCKpuZ39qNKS5utpDDmOC',
#     'id': '4cCKpuZ39qNKS5utpDDmOC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a698ef55c1dd0a95666e7edd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a698ef55c1dd0a95666e7edd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a698ef55c1dd0a95666e7edd',
#       'width': 64}],
#     'name': 'Lovers Who Uncover',
#     'release_date': '2007-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4cCKpuZ39qNKS5utpDDmOC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2bDSLK8y2edA9n2TPbzv6h'},
#      'href': 'https://api.spotify.com/v1/artists/2bDSLK8y2edA9n2TPbzv6h',
#      'id': '2bDSLK8y2edA9n2TPbzv6h',
#      'name': 'The Little Ones',
#      'type': 'artist',
#      'uri': 'spotify:artist:2bDSLK8y2edA9n2TPbzv6h'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7K3zpFXBvPcvzhj7zlGJdO'},
#      'href': 'https://api.spotify.com/v1/artists/7K3zpFXBvPcvzhj7zlGJdO',
#      'id': '7K3zpFXBvPcvzhj7zlGJdO',
#      'name': 'Crystal Castles',
#      'type': 'artist',
#      'uri': 'spotify:artist:7K3zpFXBvPcvzhj7zlGJdO'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3VQtUiBsrl1qXskSbtdQzi'},
#      'href': 'https://api.spotify.com/v1/artists/3VQtUiBsrl1qXskSbtdQzi',
#      'id': '3VQtUiBsrl1qXskSbtdQzi',
#      'name': 'Lazar',
#      'type': 'artist',
#      'uri': 'spotify:artist:3VQtUiBsrl1qXskSbtdQzi'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'disc_number': 1,
#    'duration_ms': 311226,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCN30600155'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3YDbCeUmo9V4ZM3c8b8KF0'},
#    'href': 'https://api.spotify.com/v1/tracks/3YDbCeUmo9V4ZM3c8b8KF0',
#    'id': '3YDbCeUmo9V4ZM3c8b8KF0',
#    'is_local': False,
#    'name': 'Lovers Who Uncover - Crystal Castles Vs. The Little Ones',
#    'popularity': 37,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3YDbCeUmo9V4ZM3c8b8KF0'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-02-12T13:08:50Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22ndnwvcjcizrvkpk5dfc5gbi'},
#    'href': 'https://api.spotify.com/v1/users/22ndnwvcjcizrvkpk5dfc5gbi',
#    'id': '22ndnwvcjcizrvkpk5dfc5gbi',
#    'type': 'user',
#    'uri': 'spotify:user:22ndnwvcjcizrvkpk5dfc5gbi'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2EO56JK4txid1Pss9GVbOL'},
#       'href': 'https://api.spotify.com/v1/artists/2EO56JK4txid1Pss9GVbOL',
#       'id': '2EO56JK4txid1Pss9GVbOL',
#       'name': 'Stars',
#       'type': 'artist',
#       'uri': 'spotify:artist:2EO56JK4txid1Pss9GVbOL'}],
#     'available_markets': ['AU', 'NZ', 'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/68jZlA38aXlAaPRSzckdX0'},
#     'href': 'https://api.spotify.com/v1/albums/68jZlA38aXlAaPRSzckdX0',
#     'id': '68jZlA38aXlAaPRSzckdX0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c0d1ca5bf018468d18d6172d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c0d1ca5bf018468d18d6172d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c0d1ca5bf018468d18d6172d',
#       'width': 64}],
#     'name': 'Set Yourself On Fire',
#     'release_date': '2004-10-12',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:68jZlA38aXlAaPRSzckdX0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2EO56JK4txid1Pss9GVbOL'},
#      'href': 'https://api.spotify.com/v1/artists/2EO56JK4txid1Pss9GVbOL',
#      'id': '2EO56JK4txid1Pss9GVbOL',
#      'name': 'Stars',
#      'type': 'artist',
#      'uri': 'spotify:artist:2EO56JK4txid1Pss9GVbOL'}],
#    'available_markets': ['AU', 'NZ', 'US'],
#    'disc_number': 1,
#    'duration_ms': 256053,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CAAA10400901'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5oSSFX46m6u3UFLoouLlTw'},
#    'href': 'https://api.spotify.com/v1/tracks/5oSSFX46m6u3UFLoouLlTw',
#    'id': '5oSSFX46m6u3UFLoouLlTw',
#    'is_local': False,
#    'name': 'Your Ex-Lover Is Dead',
#    'popularity': 49,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5oSSFX46m6u3UFLoouLlTw'},
#   'video_thumbnail': {'url': None}}]

# %%
len(tracks)
# Out:
# 202

# %%
# Getting all the artists

def get_artists_from_playlist(playlist_id):
    
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    
    artists = []
    
    for track in tracks_from_playlist:
        artists_info = track['track']['artists']
        
        for artist_info in artists_info:
            artists.append(artist_info['name'])
    
    return list(set(artists))

# %%
# Getting all the artists IDs

def get_artists_ids_from_playlist(playlist_id):
    
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    
    artists_ids = []
    
    for track in tracks_from_playlist:
        artists_info = track['track']['artists']
        
        for artist_info in artists_info:
            artists_ids.append(artist_info['id'])
            
    return list(set(artists_ids))

# %%
artists = get_artists_from_playlist("5LJ68O8CE7hg9oAm2vYk5K")
artists
# Out:
# ['Husbands',
#  'Flight Facilities',
#  'Christine Hoberg',
#  'Benny Sings',
#  'La Dispute',
#  'Phantogram',
#  'dandelion hands',
#  'Attic Abasement',
#  'Pinback',
#  'Freelance Whales',
#  'The Books',
#  'Big Scary',
#  'Taba Chake',
#  'WHY?',
#  'Darwin Deez',
#  'Motion City Soundtrack',
#  'Delta Sleep',
#  'Grandaddy']

# %%
artists_ids = get_artists_ids_from_playlist("12Wbv8sIx84T5uh6iOoJ7V")
artists_ids
# Out:
# ['0n94vC3S9c3mb2HyNAOcjg',
#  '6107PIkQDuEUcdpZqSzQsu',
#  '7IAFAOtc9kTYNTizhLSWM6',
#  '53A0W3U0s8diEn9RhXQhVz',
#  '5Ld19xtpAR80G2boTcHaVx',
#  '3XHO7cRUPCLOr6jwp8vsx5',
#  '2cCUtGK9sDU2EoElnk0GNB',
#  '6FQqZYVfTNQ1pCqfkwVFEa',
#  '4ERtgeBbWRkFzIz6LaFCeY',
#  '0N3qLnfGCy4AvCUpnemNLn',
#  '5Lm1CMoa8VOCBCLZesAcvc',
#  '2EO56JK4txid1Pss9GVbOL',
#  '6AnOY77z51J14nEUVsFKTy',
#  '2Z7gV3uEh1ckIaBzTUCE6R',
#  '7FU0xCgmSYQEiBeevUqQ4S',
#  '4yvcSjfu4PC0CYQyLy4wSq',
#  '1r1uxoy19fzMxunt3ONAkG',
#  '2RwfRD2vlkdztGtVXENShq',
#  '4gHcu2JoaXJ0mV4aNPCd7N',
#  '5o8Wylae9k23IEJMIiwd8s',
#  '1QAJqy2dA3ihHBFIHRphZj',
#  '6pmxr66tMAePxzOLfjGNcX',
#  '0YrtvWJMgSdVrk3SfNjTbx',
#  '1Tp7C6LzxZe9Mix6rn4zbI',
#  '0epOFNiUfyON9EYx7Tpr6V',
#  '5sXaGoRLSpd7VeyZrLkKwt',
#  '3NBmfDV6Yh3hjuQUBVvYgO',
#  '0xIsWKGGU3QjOvNp3l4jmo',
#  '0syIRg9MPSpJIC0QCPUaHB',
#  '7blXVKBSxdFZsIqlhdViKc',
#  '66mL7YE8rG9eCu4QgM64m4',
#  '7IfZ8AcE6F4PZVtT8d0JE3',
#  '7K3zpFXBvPcvzhj7zlGJdO',
#  '26FGaBmX3yqXeFp3rTPWyp',
#  '5cxol8ruhBU1QpUick7A42',
#  '7lQKE6HaKQcCsgLRMhsh5W',
#  '4I2BJf80C0skQpp1sQmA0h',
#  '1BlsomJZZh7jhA7IvgS1Al',
#  '1ctkBmvz80MGyi72Ix055S',
#  '3IunaFjvNKj98JW89JYv9u',
#  '41y1iPh0WqB7tyGdzyeinZ',
#  '1BPsbKiNgav1TY1ITIU8C5',
#  '1bYTiIHnxEdBncCHYCfE4j',
#  '1z2SrszsRmq47kDhBAnyNS',
#  '4qU7IJSReZnsLy5907Mtau',
#  '2JSc53B5cQ31m0xTB7JFpG',
#  '5ERkupmHea6uS0nwKr2zcz',
#  '4M5nCE77Qaxayuhp3fVn4V',
#  '4qOzMSukiZoiSjPQw8Zs7s',
#  '1Z2KInfSmPOzAIYyiaXeti',
#  '3wWtfT7S2uVJJ3hGZlOLkZ',
#  '2D0wm8aDnVrcljPwg2GM75',
#  '3AcBSoCVhxILXJnfLcJb66',
#  '027TpXKGwdXP7iwbjUSpV8',
#  '09b4q9Vfmuvxb8LuOrhp7W',
#  '5EM6xJN2QNk0cL7EEm9HR9',
#  '3kE0TeA4n6FZD1UG6ctB0m',
#  '7ItbAZITSFxSy5LJChXe18',
#  '2FUIaEhxMNdiBpO8ykabdP',
#  '63MQldklfxkjYDoUE4Tppz',
#  '02YLJJnWC7YQVixkjEBRn7',
#  '2SlMPjZm02pC12ODpApdhB',
#  '0lPhSdyfILTWuDUWJRyAk7',
#  '7FDlvgcodNfC0IBdWevl4u',
#  '6AyATGg7mDgBlZ4N5uNog0',
#  '20JZFwl6HVl6yg8a4H3ZqK',
#  '2d1iZa3wlO73YOM6tCeWSI',
#  '28dDyPkw069ypiqC78dhRb',
#  '4LEiUm1SRbFMgfqnQTwUbQ',
#  '0aLsJXIaJ6MMCZIzaGpMaX',
#  '163tK9Wjr9P9DmM0AVK7lm',
#  '1btWGBz4Uu1HozTwb2Lm8A',
#  '3zIJJVhqINXeuLWMbZdlbY',
#  '5SVFuUaS3BKAdJs6I8rVa4',
#  '4rUMcxwZhidyj6FTbMSXse',
#  '7ucqItQmz1PCNHBFSbr0ki',
#  '586uxXMyD5ObPuzjtrzO1Q',
#  '0AdDjXozGY1mLZrjCOcE8O',
#  '336vr2M3Va0FjyvB55lJEd',
#  '1UQRtt7eHW6Bt4INNTUtb3',
#  '6qiGjRyN7TJ1GA2nXF68Hi',
#  '26GHRG8x1F4AzbCKzUaIbw',
#  '7giUHu5pv6YTZgSkxxCcgh',
#  '4nzV0hThyodYzrwksnS86G',
#  '7MOxmVjcx5HWoEu9pBWXT3',
#  '7oRT0oC3vhUGQJCL6CYYzk',
#  '5o206eFLx38glA2bb4zqIU',
#  '77BznF1Dr1k5KyEZ6Nn3jB',
#  '5BvJzeQpmsdsFp4HGUYUEx',
#  '6QKDcdjtwqu4E7rztEUQu5',
#  '2ayD3f20lm9a4aKNtg2sUm',
#  '0BVWMc7JEHdh2Ku6xgKuYL',
#  '5Bcrb5qQMVTEbJ43fdIS4A',
#  '1Li0eIWeMeWcOOWpImcG9H',
#  '1vkWdqcabQ1swciXipkLBj',
#  '1ZtnMtzSrxGf5dt0PPLvAC',
#  '79hrYiudVcFyyxyJW0ipTy',
#  '3kzwYV3OCB010YfXMF0Avt',
#  '5cIc3SBFuBLVxJz58W2tU9',
#  '2dfxY7YDuYCUtWFzWTS6IR',
#  '2HubQ6TEbD7HknCNrBsqhR',
#  '3gXlFR0nVmanIwiMZ8SCnj',
#  '5schNIzWdI9gJ1QRK8SBnc',
#  '5YltHxThwwuFhikvggRu5M',
#  '3SBeVI3ELQKQTEDoQ9ztq9',
#  '44DUgsrbRUlhwfLyj4ySUB',
#  '5qQdzyIlYfzICKOVdb7XvY',
#  '6GpcBKNmZDIrRzYkPJu7Wd',
#  '1zXMNLcTn3CMhVKOQ9DSUp',
#  '0slVGXBggrLglTLNKbeEyW',
#  '3Kthx6vfOdyrwpE1mjsyb8',
#  '6d4jrmreCmsenscuieJERc',
#  '0oSGxfWSnnOXhD2fKuz2Gy',
#  '16eRpMNXSQ15wuJoeqguaB',
#  '2Ijj8pkgSpxa6Il5BxI7ms',
#  '5vdQYwhaxOpaSV8s7AjjH6',
#  '46CitWgnWrvF9t70C2p1Me',
#  '2x7EATekOPhFGRx3syMGEC',
#  '6Xb4ezwoAQC4516kI89nWz',
#  '4fw9oPmbbmHW5aAJpkJdlI',
#  '7o96HO2zrujyATtVsqGhh3',
#  '0QNjXIQx37k8fIIzO4g71q',
#  '68524z8sd176IRenNb1Fjy',
#  '2KjAo6wVc9d2WcxdxSArpV',
#  '64YVotBSFQoRt2TWCkGFqy',
#  '4tvKz56Tr39bkhcQUTO0Xr',
#  '0UQCSEnTVyI8gtCVEeJMKN',
#  '4o16FybIZV7WPD7tOl7PUd',
#  '6fZudW7fIeAYmGoSpl8mAv',
#  '4qOVAE5WtSf1lQ9Fi6jxXi',
#  '12KsgeavNVg66cW2frw3j2',
#  '5yV1qdnmxyIYiSFB02wpDj',
#  '59RNNqeEfkq3X5pfOQxZ3C',
#  '36057fby7tY856T2vg7jQj',
#  '0Raaw7kr1Vzat4ZvHzjsJR',
#  '0wyMPXGfOuQzNR54ujR9Ix',
#  '7KGI0OwY8iAL5rI5p47YyK',
#  '1zNqQNIdeOUZHb8zbZRFMX',
#  '3VAxb3UskTNiHAKh4UeOEv',
#  '0rZp7G3gIH6WkyeXbrZnGi',
#  '3DtHAw4MrjXhVFotN5n8fZ',
#  '35l9BRT7MXmM8bv2WDQiyB',
#  '3VQtUiBsrl1qXskSbtdQzi',
#  '0ZxZlO7oWCSYMXhehpyMvE',
#  '6G7P2EzH5A36ujN9VPm4B0',
#  '3MZsBdqDrRTJihTHQrO6Dq',
#  '7FBcuc1gsnv6Y1nwFtNRCb',
#  '4MXUO7sVCaFgFjoTI5ox5c',
#  '634K1Y2zhBHexel2Ma4xsC',
#  '1WrqUPWlHN5FXCRcQgrkas',
#  '1XwRhEHqiCVgiEJQk66fyy',
#  '0nJaMZM8paoA5HEUTUXPqi',
#  '2ATweaQe83QUQVjM8LMh7J',
#  '0nuq0P5rPEpF6oFM4PTia5',
#  '21XbnrbEMUTZelIfoV12hC',
#  '3gd8FJtBJtkRxdfbTu19U2',
#  '3pTE9iaJTkWns3mxpNQlJV',
#  '5QdyldG4Fl4TPiOIeMNpBZ',
#  '2kbAovdYb7krLSGdOrBMRu',
#  '0tC995Rfn9k2l7nqgCZsV7',
#  '54Bjxn26WsjfslQbNVtSCm',
#  '3nnQpaTvKb5jCQabZefACI',
#  '0BzqUvjgztIQEyizxqj2xP',
#  '2bDSLK8y2edA9n2TPbzv6h',
#  '4bBaa9aj9JKI1tp7RZecxR',
#  '6FBDaR13swtiWwGhX1WQsP',
#  '4zrFO6P7G6EZry0pfxMfKT',
#  '0botW5W7KGHTm8BkLemEH8',
#  '246dkjvS1zLTtiykXe5h60',
#  '2tYXwM1rLFrTBtYHY8JpnN',
#  '3Jy7XwrGPgOEq4OxRODWbf',
#  '6hQS54VPpxunuwR0W7usuo',
#  '6Bo5UEoUopq42HZX3apU1w',
#  '0qG3lxHmrUeKzL1BJJ7IBN',
#  '6imbHAlhHrFwtsOgqpeBK2',
#  '5zlnl1lFTTaETmaKci4V6j',
#  '2sNHl4oXsU0DVTy9u1otGt',
#  '0y0UzT7xPdd9niCbsODXES',
#  '3BwypqKeCj1DVIoEFwoz3S',
#  '5LkgVE79AHNZN7kMukfJFv',
#  '56ZTgzPBDge0OvCGgMO3OY',
#  '4wXchxfTTggLtzkoUhO86Q',
#  '2DtidViVelNGRQW2Znq5Mf',
#  '5ZyTLGmGVyPcuv17gy4fvw',
#  '6bmlMHgSheBauioMgKv2tn',
#  '19zqV9DV3txjMUjHvltl2D',
#  '2TuVzZPwEPqpstqmA0qLl6',
#  '59KX7XUUgAOOo5IyDjca0T',
#  '7Il2FrLyoQt0JlyhJRDL1c']

# %%
track_ids = [track['track']['id'] for track in tracks]
track_ids
# Out:
# ['0A0eOcimSNRs2EQQlH7FFJ',
#  '0MtVmhAx6CxNuxFIUc6Mj9',
#  '6aUAF8JOd8zEl41B6I18xL',
#  '2vGvPQNnyybJmiqpr1HiKX',
#  '1PuLHwFZoh5qYK89I5YBdZ',
#  '0XqvweqwDQluyCKyK25XqC',
#  '3KkXRkHbMCARz0aVfEt68P',
#  '5m9bm8tBxyhvKv41tMAdnv',
#  '6r5tlCMur8Vngv3n0DzOFl',
#  '3HQdwlovzULm18PjvlA5wz',
#  '1Jte640nBiOWyuD7N0odNZ',
#  '3HfSYACG5O3cio4dpHujWo',
#  '4UdckfJgnMiFzY2leDJ11v',
#  '7w5cxTEzp1rfV3KCy0Bd5N',
#  '2DFRFqWNahKtFD112H2iEZ',
#  '49WL7NYewiv6xPVgroXmKz',
#  '3Ed55g8hCz1GmqRTelIPIW',
#  '5TjAhRtHiLjCrzuOhgk50U',
#  '4f1n0muKxA870NYsPmraLN',
#  '0ytcZAli1HSG5qHNp76y6Y',
#  '78dUBuP4dmw7krQz2yEI97',
#  '0VqU5fPMcFo3iH1aWlDevK',
#  '0WSPIU3Y3bNXsGeKnzSnt1',
#  '1ogk8gkNwRw9iHONH2CAna',
#  '5AGC0c1Hqv2iiUpvvxVexq',
#  '7zfTF24acTKL42XSfzGETi',
#  '4Qq8rERaPWkDuZsvSWR9LL',
#  '2LWW6D1zabtolij6KFXQYm',
#  '0QUiguzo0mWdlBk6Nvujic',
#  '2y0ksBOhMh9hbJRLTNK8jC',
#  '78J9MBkAoqfvyeEpQKJDzD',
#  '73M2Vb5MfZh8iGKudkMtlw',
#  '3nATeGcFdtkhpUrRvgr667',
#  '0pdKRp2sUthTPe7RLWpPqQ',
#  '1tSVf4MEdh8kVwKCmZw6uc',
#  '6HTVZeVQ9J6Uiq6tHESxU9',
#  '3RpwjGzgb8QAuOnZbdDZZs',
#  '3cUxncrTWSA9lhlQbuIwUY',
#  '7EaxLW81WCgYuHSu6UBcMa',
#  '1tGfetmGzNQeJ7AZUhCaar',
#  '0FfZudphGgQTGeEV6AhmOs',
#  '5d8CreUdJvZejvTUo1IHLw',
#  '4CwpP3vWh0f5VsEmvdOWib',
#  '6a20J6YFMYUjUZ7WnuJYZu',
#  '04NQ1q92DRbxWq6lhpVVDQ',
#  '4mCF3EBgGPSqmEm205KBAV',
#  '4abEe6s1Ja2qSxqC6BUzn1',
#  '6AYFKOPbmd12rUP5DalRwB',
#  '1TJlbxArMUQca5A3tfNyl2',
#  '0DlTCllcloMx4ENilIfxan',
#  '6YXbSjabsKQ1pNvj6zcJ9V',
#  '7mMlbJlXXo2mRtQ4R9sIzD',
#  '1VGCIpDw7EJG3oIuw7Hnnq',
#  '6ug8xD1Q4jhgfE8t7r2ZKl',
#  '1dKyBRZ7ckTsgdzRoWdgRY',
#  '1zUj5lTHBiu3EkNr8KB27x',
#  '5lmCkYVA7AFTHexCHJp2VK',
#  '3czU3hYMIg7bdfVFXJWCvI',
#  '5qo32EQuOBG9qvs3Hf2FYZ',
#  '1kjaDbJzIBjuKxF2hk6ACj',
#  '3WtB2who5tPeyzpe2rAoPk',
#  '3NajfY7p2Si4qVvHba51X3',
#  '74X1epeRufHckhuX1KFD04',
#  '4nrdAPKfJDJ8Iiifa9WvD9',
#  '0nMqu5vN44GNv8UOQxmBJK',
#  '5xwKCPdE3kyU0XwqfbyQsx',
#  '4ufN2o3Rf6LN5Z0XaqJXIz',
#  '27LyQFdQbui4TnRs05cZ8C',
#  '0ESvfrHfNuAtkZp8SMJBOY',
#  '0eVYGqIPngJQUeRwGeVeXG',
#  '3irtiZ6iy1C7CmMdzF11rT',
#  '6rEkaGgEj1HLWZ9mjcZDjP',
#  '5eeMft4YZx0Xdf9yJPNZJY',
#  '0jcHQTvfHCH1LETpdMdHJo',
#  '7oJmIBxEAYjfkS7lhZ7M1S',
#  '2ZzoFGdygE4uLVHUGAaR0O',
#  '7HHwxrSIIqyIMmpbSfgXeA',
#  '47DKI4RxI8ZW0sBqDenMhO',
#  '299KUyIYhezxrtXiwNamtP',
#  '0DwaOWI1kC2s98qLj0LTDd',
#  '3V3PN2Rs7qjVcnBi60QdMb',
#  '1NodY8JMQCZAwpNd6Rsqew',
#  '2SAr2lP8GwNYcJvbAVTKxi',
#  '0DRvClQbN9znQ295sx76VC',
#  '6xZ3PWSh0duo0ETm4lJ3lF',
#  '5G89r6tEKp9ZrR3xivmMET',
#  '4OIuUoYoO87LnzzaHNp1Ej',
#  '1GxNPd5r7D1zChEMuMhue0',
#  '2WsPW6yawWU8zczAeKk4c0',
#  '4qyfir5Yr7nfo05g6cyFMT',
#  '6lFHBbN3sDmSTqpEdZyBGv',
#  '58rs5ZN3jjZ03rOuVyPNZb',
#  '0JXKS3yn0oeSBeji20J523',
#  '1mzjbH3G6oEm2OUTpXOS6f',
#  '2z37pTrYrn8ncBt8QhxIl0',
#  '6Py8QOQ4I1286xM9KncPQ4',
#  '06OLH1cjQrSuWrqg7FXTD3',
#  '51Yy4jTMPlq0Qwnn53id64',
#  '4PMvRfhHAx5j6Bb3XsFLoq',
#  '6tqzOYuE3lrNVPDgtF3MjM',
#  '7tvURb3EutC5eHJQ1QoNTq',
#  '6oVm5ocTB8B0rjO5dZk8Px',
#  '3rTnGUeDrnZV22DvRuUuXr',
#  '085evEw0dS7ODLc3ZCX0vq',
#  '2nwxVkDbM9Y7plRSKKfIcT',
#  '4aPl9DHXAqiYJUdjmBk4wf',
#  '71HEg3bYLyMAxHuJ3a6KIM',
#  '2o3jyT6JzyrpRncOVIxLLl',
#  '03ECtgB8cdmgHB3s6aeLGj',
#  '1Dp7JGFNjvg8Nk0CtMCcnr',
#  '3dwjSIuxyU6jLbfRRt5fX4',
#  '4tGQUAnrOXuM3epCM8OBYC',
#  '1XQnZTR0ER8y5fGO17uX1R',
#  '0guNjayAfHBgG1BPhkhT3d',
#  '6ZzQ76i9WDdVmwVeDQIcJz',
#  '44alNkXsYnTyPnkMdohBcx',
#  '05QeyKGAn4TZrv41tMiD1A',
#  '39V80DsHqas6AxqoVCVDIr',
#  '6dDXhN1Gssy8qonfDEa3EI',
#  '7ldIYiFIvxPyTiy0iO9UqV',
#  '71WzoGZcDWzrKZqSkiY3Tz',
#  '6b7j9PK107JFAb4OM2loie',
#  '67R4hNuwDWxDYGEd1lVlru',
#  '7swTZr50nSpeq9469IJ9LI',
#  '2AJkpwkDvAoj9al2tBWfK7',
#  '3WVBQjDRoUUTJnWVaUUEHL',
#  '5GDJpB4k5yzzjjNbi3MnTz',
#  '5OQlzJEpnbSd3f4ZBdh1lI',
#  '7Jh1bpe76CNTCgdgAdBw4Z',
#  '54rZE6vIzFU7cKld28NE7s',
#  '17b8JfOB3C9eSzockIBgvZ',
#  '4Pf4pygB5mb8PtEr1SMK1u',
#  '6dpPkJIg1nGcvcvFC1aXUR',
#  '0jw2IKm30sbb6kK2WgHvmn',
#  '307cqh2ACTzBm3deY5uVzs',
#  '3KhDqe6lwslwDsDGFq9cvq',
#  '3vhQHYQ6Lz08VzUuERJ06W',
#  '2jpuRZSbcBgm7jgJy3ys3r',
#  '68wibJU4yMiqNX79IaLAsN',
#  '0muYLof9H50ElzamEgi6nt',
#  '7DqOEFNBLOfF2X24eXbG2z',
#  '1NawD4ezwYuCtues1xG2Xj',
#  '3GhY9OW479kbAQvnlR0uAt',
#  '0chBzUSAfMg133RaYd6b7X',
#  '2qeGrFbgL4St7P4ArgXCS9',
#  '34fW9WmeI49SUTOTwW91kP',
#  '3gd9jFyf2AhJPi1HqHUVFP',
#  '0RMrqldYnjyoZziGlIvton',
#  '3biMJs3xhRTg13aZEWukty',
#  '67AmB2gk9L41eVSy590o1v',
#  '2SYWArhFYrwDYm0gM1aonU',
#  '1YVVAiBD5WhX2ZdHtlSOhz',
#  '1G1zhTPT7ZlgZHsyjelcQg',
#  '7eJMfftS33KTjuF7lTsMCx',
#  '3xxz277NbYSFLbj1DRYtsf',
#  '2lffRiAET2Xt6BNb4EmkS2',
#  '2m1W73aJNII9wafWkDn8S0',
#  '6x14wL9HvABR2Rix8N88EH',
#  '6xMFDLtFIiObaAuB42qHGW',
#  '669PEr8I3wOswY8BANBpdh',
#  '65wICNTM2s1PwXSgKt8f0a',
#  '0tutU5E5kMR3bY8sZllpoJ',
#  '1mGppNewxmuC9tpXhgZ2kO',
#  '5yGZ0DhhktOyE2sPPSX2Q8',
#  '2ZYBwkmtYhgUj1A7teYAZ7',
#  '1AdYZ6X00nXmO613Y7GJOl',
#  '0GevyB8xMZvEMNtyVCOxLf',
#  '1K0AENxzuLi4M420wUlvPT',
#  '0yc6Gst2xkRu0eMLeRMGCX',
#  '0qnSjipvB268SHMbNSxZ7y',
#  '1SKPmfSYaPsETbRHaiA18G',
#  '7qH9Z4dJEN0l9bidizW7fq',
#  '2KCqAdd2ad0hpJc5ySoTE8',
#  '76bcaYeKOKTrj9lEc9BZFU',
#  '2IhUmUhs9gCN2mCCuQHIPJ',
#  '78phUJYhGDpYur3XNICQQY',
#  '1uP8UVMXcTJn28TbhfR2Wo',
#  '36xZeDLfY3pSGZdQadvEvd',
#  '6DvMHPpNxxozZYyL9WjK2O',
#  '7i3MO9TWVzZyfLghMs6qH5',
#  '5q2xlArAzx7UHtbDSwIYPJ',
#  '2Wl4MbBRtan8gr0C8qUSGT',
#  '57MkRx712OdCQFCD2F4Yzc',
#  '58UM4xyufOAwhpvmfCBPyD',
#  '37mfTcSlX60JtAvAETytGs',
#  '4qx6KUiBAsuZB9ubcreapu',
#  '7biIPXNwf5SgDSlLChMvC6',
#  '2xIed9JHx5IuZ8T16JGOOM',
#  '4LDOieBPdFL4E8Z5raYuoq',
#  '0P3IyyiJecMoAX9Q4cbwHX',
#  '3UKvS7mLIsv7HvFQHQNRP8',
#  '3EIQofQf9NloNNmvg45MFE',
#  '2eDRSAU65nsBDlCzde45Vd',
#  '7hzgk557YLr0722EFkmp9Z',
#  '32XCjURMIi6zTRriXP8RF2',
#  '0zRCHQtrCsAaCSvxtexSf0',
#  '4i3txPQIUV4eC9g9FBpi9I',
#  '5BeYGBDPpCICt6WwrCaCHL',
#  '31Xlp8YDrHFNN54Y2F8fB8',
#  '46Xnj8vZFwOZCE4aZNXlTf',
#  '3YDbCeUmo9V4ZM3c8b8KF0',
#  '5oSSFX46m6u3UFLoouLlTw']

# %%
sp.audio_features(track_ids[:100])[0]
# Out:
# {'danceability': 0.291,
#  'energy': 0.319,
#  'key': 7,
#  'loudness': -10.465,
#  'mode': 1,
#  'speechiness': 0.0306,
#  'acousticness': 0.791,
#  'instrumentalness': 0.468,
#  'liveness': 0.0692,
#  'valence': 0.038,
#  'tempo': 103.793,
#  'type': 'audio_features',
#  'id': '0A0eOcimSNRs2EQQlH7FFJ',
#  'uri': 'spotify:track:0A0eOcimSNRs2EQQlH7FFJ',
#  'track_href': 'https://api.spotify.com/v1/tracks/0A0eOcimSNRs2EQQlH7FFJ',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0A0eOcimSNRs2EQQlH7FFJ',
#  'duration_ms': 323280,
#  'time_signature': 3}
